# %% [markdown]
# <a href="https://colab.research.google.com/github/senaanlass/AirbnbProject/blob/main/SenanurAnla%C5%9F.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from pandas.api.types import CategoricalDtype

# %% [markdown]
# # Yeni Bölüm

# %%
sns.set(rc={'figure.figsize':(5,5)})

# %%
df = pd.read_csv ('AB_NYC_2019.csv')
df.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
# ...

# %%
df.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %%
df['neighbourhood']
# Out:
# 0                Kensington
# 1                   Midtown
# 2                    Harlem
# 3              Clinton Hill
# 4               East Harlem
#                 ...
# 48890    Bedford-Stuyvesant
# 48891              Bushwick
# 48892                Harlem
# 48893        Hell's Kitchen
# 48894        Hell's Kitchen
# Name: neighbourhood, Length: 48895, dtype: object

# %%
df[['neighbourhood']]
# Out:
#             neighbourhood
# 0              Kensington
# 1                 Midtown
# 2                  Harlem
# 3            Clinton Hill
# 4             East Harlem
# ...                   ...
# 48890  Bedford-Stuyvesant
# 48891            Bushwick
# 48892              Harlem
# 48893      Hell's Kitchen
# 48894      Hell's Kitchen
#
# [48895 rows x 1 columns]

# %%
df["neighbourhood"].head()
# Out:
# 0      Kensington
# 1         Midtown
# 2          Harlem
# 3    Clinton Hill
# 4     East Harlem
# Name: neighbourhood, dtype: object

# %%
df[["neighbourhood","room_type"]]
# Out:
#             neighbourhood        room_type
# 0              Kensington     Private room
# 1                 Midtown  Entire home/apt
# 2                  Harlem     Private room
# 3            Clinton Hill  Entire home/apt
# 4             East Harlem  Entire home/apt
# ...                   ...              ...
# 48890  Bedford-Stuyvesant     Private room
# 48891            Bushwick     Private room
# 48892              Harlem  Entire home/apt
# 48893      Hell's Kitchen      Shared room
# 48894      Hell's Kitchen     Private room
#
# [48895 rows x 2 columns]

# %%
df[["room_type","price","minimum_nights"]]
# Out:
#              room_type  price  minimum_nights
# 0         Private room    149               1
# 1      Entire home/apt    225               1
# 2         Private room    150               3
# 3      Entire home/apt     89               1
# 4      Entire home/apt     80              10
# ...                ...    ...             ...
# 48890     Private room     70               2
# 48891     Private room     40               4
# 48892  Entire home/apt    115              10
# 48893      Shared room     55               1
# 48894     Private room     90               7
#
# [48895 rows x 3 columns]

# %%
df['room_type'].unique()
# Out:
# array(['Private room', 'Entire home/apt', 'Shared room'], dtype=object)

# %%
df['longitude'].unique()
# Out:
# array([-73.97237, -73.98377, -73.9419 , ..., -73.87727, -73.93614,
#        -73.80844])

# %%
df['availability_365'].value_counts()
# Out:
# 0      17533
# 365     1295
# 364      491
# 1        408
# 89       361
#        ...
# 195       26
# 183       24
# 196       24
# 181       23
# 202       20
# Name: availability_365, Length: 366, dtype: int64

# %%
df['room_type'].value_counts()
# Out:
# Entire home/apt    25409
# Private room       22326
# Shared room         1160
# Name: room_type, dtype: int64

# %%
df['calculated_host_listings_count'].value_counts()
# Out:
# 1      32303
# 2       6658
# 3       2853
# 4       1440
# 5        845
# 6        570
# 8        416
# 7        399
# 327      327
# 9        234
# 232      232
# 10       210
# 96       192
# 12       180
# 13       130
# 121      121
# 11       110
# 52       104
# 103      103
# 33        99
# 49        98
# 91        91
# 87        87
# 15        75
# 14        70
# 23        69
# 34        68
# 17        68
# 65        65
# 31        62
# 28        56
# 18        54
# 25        50
# 50        50
# 47        47
# 43        43
# 20        40
# 39        39
# 37        37
# 32        32
# 30        30
# 29        29
# 27        27
# 26        26
# 21        21
# 19        19
# 16        16
# Name: calculated_host_listings_count, dtype: int64

# %%
df['calculated_host_listings_count'].unique()
# Out:
# array([  6,   2,   1,   4,   3,   5,   7,  13,  28,  11,   8,   9,  52,
#         18,  15,  19,  10,  39,  26,  29,  12,  21,  96,  14,  34,  43,
#        121,  37,  49,  31,  91,  16,  87,  33,  23,  50,  20,  25, 232,
#         17,  47, 103,  65,  30,  27, 327,  32])

# %%
df['last_review'].unique()
# Out:
# array(['2018-10-19', '2019-05-21', nan, ..., '2017-12-23', '2018-01-29',
#        '2018-03-29'], dtype=object)

# %%
df['host_name'].unique()
# Out:
# array(['John', 'Jennifer', 'Elisabeth', ..., 'Abayomi', 'Alberth',
#        'Ilgar & Aysel'], dtype=object)

# %%
df['last_review'].value_counts()
# Out:
# 2019-06-23    1413
# 2019-07-01    1359
# 2019-06-30    1341
# 2019-06-24     875
# 2019-07-07     718
#               ...
# 2012-12-25       1
# 2013-10-01       1
# 2014-05-29       1
# 2014-04-19       1
# 2018-03-29       1
# Name: last_review, Length: 1764, dtype: int64

# %%
df['host_name'].value_counts()
# Out:
# Michael              417
# David                403
# Sonder (NYC)         327
# John                 294
# Alex                 279
#                     ...
# Rhonycs                1
# Brandy-Courtney        1
# Shanthony              1
# Aurore And Jamila      1
# Ilgar & Aysel          1
# Name: host_name, Length: 11452, dtype: int64

# %%
df['room_type'].value_counts().plot.barh()
# Out:
# <Axes: >

# %%
df['room_type'].value_counts().plot.barh().set_title('ROOMS')
# Out:
# Text(0.5, 1.0, 'ROOMS')

# %%
df['room_type'].value_counts().plot.bar().set_title('ROOMS')
# Out:
# Text(0.5, 1.0, 'ROOMS')

# %%
df['room_type'].value_counts().plot.bar().set_title('ROOMS')
plt.figure(figsize=(1,1))

# %%
 sns.barplot(x="room_type",y=df["room_type"].index,data=df,color="green").set_title('ROOMS')
# Out:
# Text(0.5, 1.0, 'ROOMS')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
# ...

# %%
df.groupby("room_type").sum().plot.pie(y="price",autopct="%.1f",ylabel="",legend=False,figsize=(5,5))
# Out:
# <ipython-input-54-54fdd8c75ddf>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby("room_type").sum().plot.pie(y="price",autopct="%.1f",ylabel="",legend=False,figsize=(5,5))
# <Axes: >

# %%
df.groupby("room_type").sum().plot.pie(y="minimum_nights",autopct="%.1f",ylabel="",legend=True,figsize=(5,5))
# Out:
# <ipython-input-55-59ee7dbc56b3>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby("room_type").sum().plot.pie(y="minimum_nights",autopct="%.1f",ylabel="",legend=True,figsize=(5,5))
# <Axes: >

# %%
sns.histplot(df["price"], kde=True, bins=100)
# Out:
# <Axes: xlabel='price', ylabel='Count'>

# %%
sns.kdeplot(df["price"])
# Out:
# <Axes: xlabel='price', ylabel='Density'>

# %%
sns.scatterplot(x="room_type",y=df["price"],data=df)
# Out:
# <Axes: xlabel='room_type', ylabel='price'>

# %%
sns.catplot(x="room_type",y="price",data=df,color="purple")
plt.title("ROOMS - PRICE")
# Out:
# Text(0.5, 1.0, 'ROOMS - PRICE')

# %%
sns.kdeplot(df["price"], shade=True)
# Out:
# <ipython-input-70-6e1ef0e267b4>:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df["price"], shade=True)
# <Axes: xlabel='price', ylabel='Density'>

# %%
sns.catplot(x="minimum_nights", y="price", hue="room_type", kind="point", data=df)

# %%
plt.title("Correlation Matrix")
sns.heatmap(df.corr())
# Out:
# <ipython-input-81-1f862cb04eec>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr())
# <Axes: title={'center': 'Correlation Matrix'}>

# %%
df.describe().T
# Out:
#                                   count          mean           std  \
# id                              48895.0  1.901714e+07  1.098311e+07
# host_id                         48895.0  6.762001e+07  7.861097e+07
# latitude                        48895.0  4.072895e+01  5.453008e-02
# longitude                       48895.0 -7.395217e+01  4.615674e-02
# price                           48895.0  1.527207e+02  2.401542e+02
# minimum_nights                  48895.0  7.029962e+00  2.051055e+01
# number_of_reviews               48895.0  2.327447e+01  4.455058e+01
# reviews_per_month               38843.0  1.373221e+00  1.680442e+00
# calculated_host_listings_count  48895.0  7.143982e+00  3.295252e+01
# availability_365                48895.0  1.127813e+02  1.316223e+02
#
#                                        min           25%           50%  \
# id                              2539.00000  9.471945e+06  1.967728e+07
# host_id                         2438.00000  7.822033e+06  3.079382e+07
# ...
